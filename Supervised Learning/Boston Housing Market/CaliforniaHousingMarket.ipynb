# %% [markdown]
# <h1><strong><u>California Housing Market Model</u></strong></h1>

# %%
# !pip install mglearn

# %%
from sklearn.datasets import fetch_california_housing
from mglearn.datasets import load_extended_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
data = fetch_california_housing(as_frame=True)

# %%
X = data.data
y = data.target

# %%
print(X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB
# None

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=23)

# %%
display(X_train.head())
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 10096  3.8194      34.0  5.034130   1.088737       698.0  2.382253     33.93
# 7835   3.3182      35.0  3.904762   0.789116       610.0  4.149660     33.91
# 13526  4.3676      28.0  6.392857   1.011905      1304.0  3.104762     34.18
# 10224  3.0893      25.0  3.835476   1.128535       755.0  1.940874     33.87
# 17037  4.2240      43.0  5.655098   1.034707      1225.0  2.657267     37.49
#
#        Longitude
# 10096    -117.94
# 7835     -118.15
# 13526    -117.30
# 10224    -117.89
# 17037    -122.25

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print("Training set score: {:.2f}".format(lr.score(X_train, y_train)))
print("Test set score: {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# Training set score: 0.60
# Test set score: 0.61

# %%
training_predictions = lr.predict(X_train)
testing_predictions = lr.predict(X_test)

# %%
train_error = np.sqrt(mean_squared_error(y_train, training_predictions))
print("Training set Root Mean Squared Error: {:.2f}".format(error))
test_error = np.sqrt(mean_squared_error(y_test, testing_predictions))
print("Test set Root Mean Squared Error: {:.2f}".format(error))
# Out:
# Training set Root Mean Squared Error: 0.72
# Test set Root Mean Squared Error: 0.72

# %%
avg_training_target = y_train.mean()
avg_test_target = y_test.mean()

# %%
train_percentage = (train_error / avg_training_target) * 100
test_percentage = (test_error / avg_test_target) * 100
print("Training set RMSE is {:.2f}% of the average target value.".format(train_percentage))
print("Test set RMSE is {:.2f}% of the average target value.".format(test_percentage))
# Out:
# Training set RMSE is 35.18% of the average target value.
# Test set RMSE is 34.79% of the average target value.
